# %% [markdown]
# # Notebook di preparazione

# %%
# !pip install pandas
# !pip install sklearn
# Out:
# Requirement already satisfied: pandas in /home/gabriele/anaconda3/envs/challenge/lib/python3.8/site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in /home/gabriele/anaconda3/envs/challenge/lib/python3.8/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in /home/gabriele/anaconda3/envs/challenge/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/gabriele/anaconda3/envs/challenge/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/gabriele/anaconda3/envs/challenge/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: sklearn in /home/gabriele/anaconda3/envs/challenge/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/gabriele/anaconda3/envs/challenge/lib/python3.8/site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: joblib>=0.11 in /home/gabriele/anaconda3/envs/challenge/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in /home/gabriele/anaconda3/envs/challenge/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.6.3)
# Requirement already satisfied: numpy>=1.13.3 in /home/gabriele/anaconda3/envs/challenge/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gabriele/anaconda3/envs/challenge/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.1.0)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# Ispezioniamo il dataset:

# %%
origin_path = "./Telco-Customer-Churn.partial.csv"

data = pd.read_csv(origin_path)

pd.set_option("max_columns", None)
data.head(10)
# Out:
#   Churn  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    No  4223-BKEOR  Female              0      No        Yes      21
# 1    No  6035-RIIOM  Female              0      No         No      54
# 2   Yes  3797-VTIDR    Male              0     Yes         No       1
# 3   Yes  2568-BRGYX    Male              0      No         No       4
# 4    No  2775-SEFEE    Male              0      No        Yes       0
# 5    No  4291-SHSBH    Male              0      No         No       7
# 6    No  4635-EJYPD    Male              0     Yes        Yes      32
# 7    No  2607-DHDAK    Male              0     Yes        Yes      72
# 8   Yes  5204-QZXPU    Male              0      No         No      19
# 9    No  0221-NAUXK    Male              0      No        Yes      10
#
#   PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 0          Yes                No             DSL                  Yes
# 1          Yes               Yes     Fiber optic                   No
# 2           No  No phone service             DSL                   No
# 3          Yes                No     Fiber optic                   No
# 4          Yes               Yes             DSL                  Yes
# 5          Yes                No     Fiber optic                   No
# 6          Yes                No              No  No internet service
# 7          Yes                No              No  No internet service
# 8           No  No phone service             DSL                   No
# 9          Yes                No              No  No internet service
#
#           OnlineBackup     DeviceProtection          TechSupport  \
# 0                   No                  Yes                   No
# 1                  Yes                   No                   No
# 2                   No                   No                   No
# 3                   No                   No                   No
# 4                  Yes                   No                  Yes
# 5                   No                   No                   No
# 6  No internet service  No internet service  No internet service
# 7  No internet service  No internet service  No internet service
# 8                   No                  Yes                   No
# 9  No internet service  No internet service  No internet service
#
#            StreamingTV      StreamingMovies        Contract PaperlessBilling  \
# 0                   No                  Yes        One year               No
# 1                  Yes                  Yes        Two year              Yes
# 2                   No                   No  Month-to-month              Yes
# 3                   No                   No  Month-to-month              Yes
# 4                   No                   No        Two year              Yes
# 5                   No                   No  Month-to-month              Yes
# 6  No internet service  No internet service        Two year               No
# 7  No internet service  No internet service        Two year              Yes
# 8                  Yes                   No  Month-to-month              Yes
# 9  No internet service  No internet service        One year              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges
# 0               Mailed check           64.85       1336.8
# 1  Bank transfer (automatic)           97.20      5129.45
# 2           Electronic check           23.45        23.45
# 3           Electronic check           70.20       237.95
# 4  Bank transfer (automatic)           61.90
# 5           Electronic check           69.55       521.35
# 6               Mailed check           18.95       613.95
# 7    Credit card (automatic)           19.80      1414.65
# 8           Electronic check           39.65       733.35
# 9  Bank transfer (automatic)           19.95        219.5

# %% [markdown]
# È sicuramente più variegato e realistico rispetto a quello dei funghi. Gia dalle prime 10 righe si può vedere che alcune celle sono vuote (riga 4, TotalCharges), le colonne hanno tipi differenti.

# %%
non_categorical = ["customerID", "SeniorCitizen", "tenure", "MonthlyCharges", "TotalCharges"]
numerical = ["SeniorCitizen", "tenure", "MonthlyCharges", "TotalCharges"]
categorical = [col for col in data.columns if col not in non_categorical]

for col in categorical:
    print(col, pd.get_dummies(data[col]), "\n")
# Out:
# Churn       No  Yes
# 0      1    0
# 1      1    0
# 2      0    1
# 3      0    1
# 4      1    0
# ...   ..  ...
# 5629   0    1
# 5630   1    0
# 5631   1    0
# 5632   0    1
# 5633   1    0
#
# [5634 rows x 2 columns]
#
# gender       Female  Male
# 0          1     0
# 1          1     0
# 2          0     1
# 3          0     1
# 4          0     1
# ...      ...   ...
# 5629       0     1
# 5630       1     0
# 5631       0     1
# 5632       0     1
# 5633       0     1
#
# [5634 rows x 2 columns]
#
# Partner       No  Yes
# 0      1    0
# 1      1    0
# 2      0    1
# 3      1    0
# 4      1    0
# ...   ..  ...
# 5629   0    1
# 5630   0    1
# 5631   0    1
# 5632   1    0
# 5633   1    0
#
# [5634 rows x 2 columns]
#
# Dependents       No  Yes
# 0      0    1
# 1      1    0
# 2      1    0
# 3      1    0
# 4      0    1
# ...   ..  ...
# 5629   1    0
# 5630   0    1
# 5631   0    1
# 5632   1    0
# 5633   1    0
#
# [5634 rows x 2 columns]
#
# PhoneService       No  Yes
# 0      0    1
# 1      0    1
# 2      1    0
# 3      0    1
# 4      0    1
# ...   ..  ...
# 5629   0    1
# 5630   0    1
# 5631   0    1
# 5632   0    1
# 5633   0    1
#
# [5634 rows x 2 columns]
#
# MultipleLines       No  No phone service  Yes
# 0      1                 0    0
# 1      0                 0    1
# 2      0                 1    0
# 3      1                 0    0
# 4      0                 0    1
# ...   ..               ...  ...
# 5629   1                 0    0
# 5630   0                 0    1
# 5631   1                 0    0
# 5632   0                 0    1
# 5633   1                 0    0
#
# [5634 rows x 3 columns]
#
# InternetService       DSL  Fiber optic  No
# 0       1            0   0
# 1       0            1   0
# 2       1            0   0
# 3       0            1   0
# 4       1            0   0
# ...   ...          ...  ..
# 5629    0            1   0
# 5630    1            0   0
# 5631    0            0   1
# 5632    0            1   0
# 5633    0            0   1
#
# [5634 rows x 3 columns]
#
# OnlineSecurity       No  No internet service  Yes
# 0      0                    0    1
# 1      1                    0    0
# 2      1                    0    0
# 3      1                    0    0
# 4      0                    0    1
# ...   ..                  ...  ...
# 5629   0                    0    1
# 5630   0                    0    1
# 5631   0                    1    0
# 5632   1                    0    0
# 5633   0                    1    0
#
# [5634 rows x 3 columns]
#
# OnlineBackup       No  No internet service  Yes
# 0      1                    0    0
# 1      0                    0    1
# 2      1                    0    0
# 3      1                    0    0
# 4      0                    0    1
# ...   ..                  ...  ...
# 5629   1                    0    0
# 5630   0                    0    1
# 5631   0                    1    0
# 5632   1                    0    0
# 5633   0                    1    0
#
# [5634 rows x 3 columns]
#
# DeviceProtection       No  No internet service  Yes
# 0      0                    0    1
# 1      1                    0    0
# 2      1                    0    0
# 3      1                    0    0
# 4      1                    0    0
# ...   ..                  ...  ...
# 5629   1                    0    0
# 5630   0                    0    1
# 5631   0                    1    0
# 5632   0                    0    1
# 5633   0                    1    0
#
# [5634 rows x 3 columns]
#
# TechSupport       No  No internet service  Yes
# 0      1                    0    0
# 1      1                    0    0
# 2      1                    0    0
# 3      1                    0    0
# 4      0                    0    1
# ...   ..                  ...  ...
# 5629   1                    0    0
# 5630   0                    0    1
# 5631   0                    1    0
# 5632   1                    0    0
# 5633   0                    1    0
#
# [5634 rows x 3 columns]
#
# StreamingTV       No  No internet service  Yes
# 0      1                    0    0
# 1      0                    0    1
# 2      1                    0    0
# 3      1                    0    0
# 4      1                    0    0
# ...   ..                  ...  ...
# 5629   0                    0    1
# 5630   0                    0    1
# 5631   0                    1    0
# 5632   0                    0    1
# 5633   0                    1    0
#
# [5634 rows x 3 columns]
#
# StreamingMovies       No  No internet service  Yes
# 0      0                    0    1
# 1      0                    0    1
# 2      1                    0    0
# 3      1                    0    0
# 4      1                    0    0
# ...   ..                  ...  ...
# 5629   0                    0    1
# 5630   0                    0    1
# 5631   0                    1    0
# 5632   0                    0    1
# 5633   0                    1    0
#
# [5634 rows x 3 columns]
#
# Contract       Month-to-month  One year  Two year
# 0                  0         1         0
# 1                  0         0         1
# 2                  1         0         0
# 3                  1         0         0
# 4                  0         0         1
# ...              ...       ...       ...
# 5629               1         0         0
# 5630               0         0         1
# 5631               1         0         0
# 5632               1         0         0
# 5633               0         1         0
#
# [5634 rows x 3 columns]
#
# PaperlessBilling       No  Yes
# 0      1    0
# 1      0    1
# 2      0    1
# 3      0    1
# 4      0    1
# ...   ..  ...
# 5629   0    1
# 5630   0    1
# 5631   0    1
# 5632   0    1
# 5633   1    0
#
# [5634 rows x 2 columns]
#
# PaymentMethod       Bank transfer (automatic)  Credit card (automatic)  Electronic check  \
# 0                             0                        0                 0
# 1                             1                        0                 0
# 2                             0                        0                 1
# 3                             0                        0                 1
# 4                             1                        0                 0
# ...                         ...                      ...               ...
# 5629                          0                        0                 1
# 5630                          0                        1                 0
# 5631                          0                        0                 1
# 5632                          0                        0                 1
# 5633                          0                        1                 0
#
#       Mailed check
# 0                1
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 5629             0
# 5630             0
# 5631             0
# 5632             0
# 5633             0
#
# [5634 rows x 4 columns]

# %% [markdown]
# Vediamo se e quanti valori nulli ci sono

# %%
for col in data.columns:
    print(col)
    print(data[col].isnull().sum(), "\n")
# Out:
# Churn
# 0
#
# customerID
# 0
#
# gender
# 0
#
# SeniorCitizen
# 0
#
# Partner
# 0
#
# Dependents
# 0
#
# tenure
# 0
#
# PhoneService
# 0
#
# MultipleLines
# 0
#
# InternetService
# 0
#
# OnlineSecurity
# 0
#
# OnlineBackup
# 0
#
# DeviceProtection
# 0
#
# TechSupport
# 0
#
# StreamingTV
# 0
#
# StreamingMovies
# 0
#
# Contract
# 0
#
# PaperlessBilling
# 0
#
# PaymentMethod
# 0
#
# MonthlyCharges
# 0
#
# TotalCharges
# 0

# %% [markdown]
# Secondo questo output non ci sono valori nulli. In realtà noi abbiamo visto però che in (4, TotalCharges) è assente il valore numerico. Questo poiché i tipi sono stringhe. Quindi nel notebook di training bisognerà convertitrli in valori numerici ed eliminare i NaN.

# %%
data.loc[4,"TotalCharges"]
# Out:
# ' '

# %% [markdown]
# ## Split del dataset in train + valid e test

# %% [markdown]
# La ragione scelta per lo split è 70-15-15. Il 15% dei dati andrà nel file di test. L'85% dei dati andrà nel file di training. Pertanto nel file di training, la porzione di training sarà circa dell'82% mentre la porzione per il validation sarà del 18%

# %%
train_data, test_data = train_test_split(data, random_state=10, test_size=0.15)

path_train = './train.csv'
path_test = './test.csv'

train_data.to_csv(path_train, index=False)
test_data.to_csv(path_test, index=False)
